# %%
import pandas as pd
print("Hello investment World")
# Out:
# Hello investment World

# %%
import pandas as pd
print("Hello investment World")
# Out:
# Hello investment World

# %%
import os
os.getcwd()
# Out:
# 'D:\\3.2'

# %%
# !pip install yfinance

# %%
import yfinance
print("yfinance installed successfully")
# Out:
# yfinance installed successfully

# %%
import yfinance as yf
import pandas as pd
df=yf.download ("AAPL",start="20150101")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'anaconda_projects',
#  'sp500.csv',
#  'sp500.csv.xlsx',
#  'week1_day1.ipynb']

# %%
import pandas as pd 
df=pd.read_csv("sp500.csv")
df.head()
# Out:
#          Date  Open  High   Low  Close  Volume
# 0  1789-05-01  0.51  0.51  0.51   0.51       0
# 1  1789-06-01  0.51  0.51  0.51   0.51       0
# 2  1789-07-01  0.50  0.50  0.50   0.50       0
# 3  1789-08-01  0.50  0.51  0.50   0.51       0
# 4  1789-09-01  0.51  0.51  0.50   0.51       0

# %%
import pandas as pd
df=pd.read_excel("sp500.csv.xlsx")
df.head()
# Out:
#          Date  Open  High   Low  Close  Volume
# 0  1789-05-01  0.51  0.51  0.51   0.51     0.0
# 1  1789-06-01  0.51  0.51  0.51   0.51     0.0
# 2  1789-07-01  0.50  0.50  0.50   0.50     0.0
# 3  1789-08-01  0.50  0.51  0.50   0.51     0.0
# 4  1789-09-01  0.51  0.51  0.50   0.51     0.0

# %%
close_prices=df["Close"]
close_prices.head()
# Out:
# 0    0.51
# 1    0.51
# 2    0.50
# 3    0.51
# 4    0.51
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(close_prices)
plt.title("SP500 Price Trend")
plt.show()

# %%
import pandas as pd
df=pd.read_excel("sp500.csv.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    39644 non-null  object
#  1   Open    39644 non-null  float64
#  2   High    39644 non-null  float64
#  3   Low     39644 non-null  float64
#  4   Close   39644 non-null  float64
#  5   Volume  39644 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  39644.000000  39644.000000  39644.000000  39644.000000  3.964400e+04
# mean     453.607212    456.211726    450.832079    453.697831  3.386416e+08
# std     1037.546812   1043.058448   1031.582159   1037.718514  7.971098e+08
# min        0.490000      0.490000      0.490000      0.490000  0.000000e+00
# 25%        8.890000      8.900000      8.880000      8.890000  0.000000e+00
# 50%       18.785000     18.835000     18.715000     18.785000  0.000000e+00
# 75%      244.072500    246.152500    241.962500    244.162500  7.372639e+07
# max     7002.000000   7002.280000   6963.460000   6978.600000  6.888367e+09

# %%
df.iloc[0]
df.iloc[:5]
df.iloc[-5:]
# Out:
#                       Date     Open     High      Low    Close        Volume
# 39639  2026-02-23 00:00:00  6901.25  6916.96  6819.82  6837.75  1.822725e+08
# 39640  2026-02-24 00:00:00  6837.37  6899.17  6815.43  6890.07  1.753847e+08
# 39641  2026-02-25 00:00:00  6915.15  6952.51  6915.15  6946.13  1.760870e+08
# 39642  2026-02-26 00:00:00  6944.74  6947.25  6859.73  6908.86  3.454065e+09
# 39643  2026-02-27 00:00:00  6856.54  6882.96  6831.74  6878.88  4.566274e+09

# %%
df[df["Close"]>4000]
# Out:
#                       Date     Open     High      Low    Close        Volume
# 38411  2021-04-01 00:00:00  3992.78  4020.63  3992.78  4019.87  2.178188e+09
# 38412  2021-04-05 00:00:00  4034.44  4083.42  4034.44  4077.91  2.241318e+09
# 38413  2021-04-06 00:00:00  4075.57  4086.23  4068.14  4073.94  2.147072e+09
# 38414  2021-04-07 00:00:00  4074.29  4083.13  4068.31  4079.95  1.963233e+09
# 38415  2021-04-08 00:00:00  4089.95  4098.19  4082.54  4097.17  2.011933e+09
# ...                    ...      ...      ...      ...      ...           ...
# 39639  2026-02-23 00:00:00  6901.25  6916.96  6819.82  6837.75  1.822725e+08
# 39640  2026-02-24 00:00:00  6837.37  6899.17  6815.43  6890.07  1.753847e+08
# 39641  2026-02-25 00:00:00  6915.15  6952.51  6915.15  6946.13  1.760870e+08
# 39642  2026-02-26 00:00:00  6944.74  6947.25  6859.73  6908.86  3.454065e+09
# 39643  2026-02-27 00:00:00  6856.54  6882.96  6831.74  6878.88  4.566274e+09
#
# [1082 rows x 6 columns]

# %%
df[(df["Close"]>4000) &(df["Volume"]>1e9)]
# Out:
#                       Date     Open     High      Low    Close        Volume
# 38411  2021-04-01 00:00:00  3992.78  4020.63  3992.78  4019.87  2.178188e+09
# 38412  2021-04-05 00:00:00  4034.44  4083.42  4034.44  4077.91  2.241318e+09
# 38413  2021-04-06 00:00:00  4075.57  4086.23  4068.14  4073.94  2.147072e+09
# 38414  2021-04-07 00:00:00  4074.29  4083.13  4068.31  4079.95  1.963233e+09
# 38415  2021-04-08 00:00:00  4089.95  4098.19  4082.54  4097.17  2.011933e+09
# ...                    ...      ...      ...      ...      ...           ...
# 39636  2026-02-18 00:00:00  6855.48  6909.12  6849.66  6881.31  3.073230e+09
# 39637  2026-02-19 00:00:00  6861.34  6879.12  6833.06  6861.89  2.922325e+09
# 39638  2026-02-20 00:00:00  6843.26  6915.86  6836.33  6909.51  3.364360e+09
# 39642  2026-02-26 00:00:00  6944.74  6947.25  6859.73  6908.86  3.454065e+09
# 39643  2026-02-27 00:00:00  6856.54  6882.96  6831.74  6878.88  4.566274e+09
#
# [1077 rows x 6 columns]

# %%
df["Return"]=df["Close"].pct_change()
df.head()
# Out:
#          Date  Open  High   Low  Close  Volume    Return
# 0  1789-05-01  0.51  0.51  0.51   0.51     0.0       NaN
# 1  1789-06-01  0.51  0.51  0.51   0.51     0.0  0.000000
# 2  1789-07-01  0.50  0.50  0.50   0.50     0.0 -0.019608
# 3  1789-08-01  0.50  0.51  0.50   0.51     0.0  0.020000
# 4  1789-09-01  0.51  0.51  0.50   0.51     0.0  0.000000

# %%
df["Return"].describe()
# Out:
# count    39643.000000
# mean         0.000305
# std          0.011444
# min         -0.204669
# 25%         -0.004408
# 50%          0.000318
# 75%          0.005239
# max          0.292818
# Name: Return, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df["Return"])
plt.title("Daily Return")
plt.show()

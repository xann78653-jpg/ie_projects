# %%
# !pip install yfinance

# %%
import yfinance
print("yfinance been installed")

# %%
import yfinance as yf
import pandas as pd
df=yf.download("AAPL",start="2020-01-01")

# %%
import os
os.listdir()

# %%
import pandas as pd
df=pd.read_csv("NASD.csv")
df.head()

# %%
df.describe()

# %%
df[df["Close"]>4000]

# %%
df["Return"]=df["Close"].pct_change()
df.head()

# %%
import matplotlib.pyplot as plt
plt.plot(df["Return"])
plt.title("Daily Return")
plt.show()

# %%
df["Close"]
